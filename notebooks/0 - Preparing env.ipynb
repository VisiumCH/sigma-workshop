# %% [markdown]
# # Agentic fighters

# %% [markdown]
# ## Preparing the env
#
# Everything is ready to be handled by UV (_pyproject.toml_ and _uv.lock_).
#
# Commands to execute:
#
# - `pip install uv`
# - `uv sync` from root, to create venv and install packages
#
# If UV does not work, we can also install the packages via pip:
#
# - `pip install -r requirements.txt`
#
# Finally, we need to load the venv:
#
# - `source ./.venv/bin/activate` --> make sure the kernel is properly selected in the notebooks

# %%
from langgraph.graph import StateGraph
